# %%
from pathlib import Path
import pandas as pd
import sqlalchemy
import sqlite3
from sqlalchemy import create_engine, inspect
from sqlalchemy.ext.automap import automap_base

# %%
database_path = Path("Resource_3/pops_cities.sqlite")

# %%
engine = sqlalchemy.create_engine(f'sqlite:///{str(database_path)}')

# %%
query = "SELECT * FROM population_city"

# %%
cities = pd.read_sql_query(query, engine)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File C:\Anaconda\Lib\site-packages\sqlalchemy\engine\base.py:3280, in Engine._wrap_pool_connect(self, fn, connection)
#    3279 try:
# -> 3280     return fn()
#    3281 except dialect.dbapi.Error as e:
#
# File C:\Anaconda\Lib\site-packages\sqlalchemy\pool\base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File C:\Anaconda\Lib\site-packages\sqlalchemy\pool\base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# --> 868     fairy = _ConnectionRecord.checkout(pool)
#     870     fairy._pool = pool
#
# ...
