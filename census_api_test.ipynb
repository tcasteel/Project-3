# %%
import requests
import pandas as pd

api_key = '0184431db018484fc683ae64e25db82f73d35f0b'

url = 'https://api.census.gov/data/2022/acs/acsse?get=NAME,K202511_001E&for=state:*&key=0184431db018484fc683ae64e25db82f73d35f0b'

# %%
response = requests.get(url)

data22 = response.json()

rent_22 = pd.DataFrame(data22)

# %%
url = 'https://api.census.gov/data/2018/acs/acsse?get=NAME,K202511_001E&for=state:*&key=0184431db018484fc683ae64e25db82f73d35f0b'
response = requests.get(url)

data18 = response.json()

rent18 = pd.DataFrame(data18)

# %%
analysis = pd.merge(rent_22,rent18,on=0)

analysis
# Out:
#                        0           1_x    2_x           1_y    2_y
# 0                   NAME  K202511_001E  state  K202511_001E  state
# 1               Arkansas           846     05           731     05
# 2                Arizona          1450     04          1036     04
# 3                Alabama           913     01           788     01
# 4                 Alaska          1329     02          1177     02
# 5             California          1870     06          1520     06
# 6               Colorado          1646     08          1289     08
# 7            Connecticut          1360     09          1171     09
# 8               Delaware          1274     10          1108     10
# 9   District of Columbia          1843     11          1516     11
# 10               Florida          1525     12          1182     12
# 11               Georgia          1269     13          1008     13
# 12                Hawaii          1813     15          1613     15
# ...

# %%
#geographical mobility in the past year in the united states

url = 'https://api.census.gov/data/2022/acs/acsse?get=NAME,K200701_001E&for=place:*&key=0184431db018484fc683ae64e25db82f73d35f0b'

response = requests.get(url)

json_response = response.json()

geo_data = pd.DataFrame(json_response[1:], columns=json_response[0])

geo_data = geo_data.rename(columns={'K200701_001E': 'Geographical Mobility total'})

geo_data = geo_data.dropna()

geo_data

geo_data['Geographical Mobility total'] = geo_data['Geographical Mobility total'].astype(int)

geo_data = geo_data.sort_values('Geographical Mobility total', ascending=False)

geo_data.head(30)
# geo_data.loc[(geo_data['state'] == '35')]
# Out:
#                                                    NAME  \
# 1399                            New York city, New York
# 238                        Los Angeles city, California
# 754                              Chicago city, Illinois
# 1784                                Houston city, Texas
# 57                                Phoenix city, Arizona
# 1640                    Philadelphia city, Pennsylvania
# 1833                            San Antonio city, Texas
# 328                          San Diego city, California
# 1755                                 Dallas city, Texas
# 1728                                 Austin city, Texas
# 332                           San Jose city, California
# 528                          Jacksonville city, Florida
# 1773                             Fort Worth city, Texas
# 1493                                Columbus city, Ohio
# 1433                     Charlotte city, North Carolina
# 855                Indianapolis city (balance), Indiana
# ...

# %%
tx = geo_data.loc[(geo_data['state']) == '48']

tx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 138 entries, 1784 to 1752
# Data columns (total 4 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   NAME                         138 non-null    object
#  1   Geographical Mobility total  138 non-null    int64
#  2   state                        138 non-null    object
#  3   place                        138 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 5.4+ KB

# %%
#pull API data by industry
agrurl = 'https://api.census.gov/data/2022/acs/acsse?get=NAME,K202403_002E&for=place:*&key=0184431db018484fc683ae64e25db82f73d35f0b'

agresponse = requests.get(agrurl)

agrjson_response = agresponse.json()

agr_data = pd.DataFrame(agrjson_response[1:], columns=agrjson_response[0])

agr_data = agr_data.rename(columns={'K202403_002E': 'Total Employed in Agriculture'})

agr_data = agr_data.dropna()

agr_data = agr_data.loc[(agr_data['Total Employed in Agriculture']) != '0']

agr_data['Total Employed in Agriculture'] = agr_data['Total Employed in Agriculture'].astype(int)

agr_data = agr_data.sort_values('Total Employed in Agriculture', ascending=False)

agr_data.head(10)
# Out:
#                               NAME  Total Employed in Agriculture state  place
# 2018           Houston city, Texas                          24439    48  35000
# 123   Bakersfield city, California                          15802    06  03526
# 2047           Midland city, Texas                          13621    48  48072
# 320        Oxnard city, California                          12883    06  54652
# 366       Salinas city, California                          11190    06  64224
# 394   Santa Maria city, California                           9037    06  69196
# 213        Fresno city, California                           8625    06  27000
# 1795  Oklahoma City city, Oklahoma                           8391    40  55000
# 271   Los Angeles city, California                           7260    06  44000
# 177        Delano city, California                           6458    06  18394

# %%
conurl = 'https://api.census.gov/data/2022/acs/acsse?get=NAME,K202403_003E&for=place:*&key=0184431db018484fc683ae64e25db82f73d35f0b'

conesponse = requests.get(conurl)

conjson_response = conesponse.json()

con_data = pd.DataFrame(conjson_response[1:], columns=conjson_response[0])

con_data = con_data.rename(columns={'K202403_003E': 'Total Employed in Construction'})

con_data = con_data.dropna()

con_data = con_data.loc[(con_data['Total Employed in Construction']) != '0']

con_data['Total Employed in Construction'] = con_data['Total Employed in Construction'].astype(int)

con_data = con_data.sort_values('Total Employed in Construction', ascending=False)

con_data.head(10)
# Out:
#                                 NAME  Total Employed in Construction state  \
# 1591         New York city, New York                          194970    36
# 271     Los Angeles city, California                          133402    06
# 2018             Houston city, Texas                          131472    48
# 63             Phoenix city, Arizona                           71545    04
# 1987              Dallas city, Texas                           70617    48
# 2076         San Antonio city, Texas                           63680    48
# 853           Chicago city, Illinois                           50507    17
# 1636  Charlotte city, North Carolina                           39871    37
# 2004          Fort Worth city, Texas                           35841    48
# 372       San Diego city, California                           34381    06
#
#       place
# 1591  51000
# 271   44000
# 2018  35000
# 63    55000
# 1987  19000
# 2076  65000
# 853   14000
# 1636  12000
# 2004  27000
# ...

# %%
mfcturl = 'https://api.census.gov/data/2022/acs/acsse?get=NAME,K202403_004E&for=place:*&key=0184431db018484fc683ae64e25db82f73d35f0b'

mfctresponse = requests.get(mfcturl)

mfctjson_response = mfctresponse.json()

mfct_data = pd.DataFrame(mfctjson_response[1:], columns=mfctjson_response[0])

mfct_data = mfct_data.rename(columns={'K202403_004E': 'Total Employed in Manufacturing'})

mfct_data = mfct_data.dropna()

mfct_data = mfct_data.loc[(mfct_data['Total Employed in Manufacturing']) != '0']

mfct_data['Total Employed in Manufacturing'] = mfct_data['Total Employed in Manufacturing'].astype(int)

mfct_data = mfct_data.sort_values('Total Employed in Manufacturing', ascending=False)

mfct_data.head(10)
# Out:
#                                       NAME  Total Employed in Manufacturing  \
# 271           Los Angeles city, California                           138065
# 1591               New York city, New York                           113263
# 853                 Chicago city, Illinois                           102217
# 2018                   Houston city, Texas                            86507
# 379              San Jose city, California                            86121
# 372             San Diego city, California                            69546
# 63                   Phoenix city, Arizona                            56466
# 979   Indianapolis city (balance), Indiana                            47016
# 2004                Fort Worth city, Texas                            46098
# 1987                    Dallas city, Texas                            45980
#
#      state  place
# 271     06  44000
# 1591    36  51000
# 853     17  14000
# 2018    48  35000
# 379     06  68000
# ...

# %%
wholeurl = 'https://api.census.gov/data/2022/acs/acsse?get=NAME,K202403_005E&for=place:*&key=0184431db018484fc683ae64e25db82f73d35f0b'

wholeresponse = requests.get(wholeurl)

wholejson_response = wholeresponse.json()

whole_data = pd.DataFrame(wholejson_response[1:], columns=wholejson_response[0])

whole_data = whole_data.rename(columns={'K202403_005E': 'Total Employed in Wholesale'})

whole_data = whole_data.dropna()

whole_data = whole_data.loc[(whole_data['Total Employed in Wholesale']) != '0']

whole_data['Total Employed in Wholesale'] = whole_data['Total Employed in Wholesale'].astype(int)

whole_data = whole_data.sort_values('Total Employed in Wholesale', ascending=False)

whole_data.head(10)
# Out:
#                                  NAME  Total Employed in Wholesale state  \
# 1591          New York city, New York                        64281    36
# 271      Los Angeles city, California                        44270    06
# 853            Chicago city, Illinois                        27751    17
# 2018              Houston city, Texas                        27300    48
# 1987               Dallas city, Texas                        17787    48
# 63              Phoenix city, Arizona                        16305    04
# 2076          San Antonio city, Texas                        14257    48
# 1859  Philadelphia city, Pennsylvania                        14117    42
# 1704              Columbus city, Ohio                        12811    39
# 2004           Fort Worth city, Texas                        11980    48
#
#       place
# 1591  51000
# 271   44000
# 853   14000
# 2018  35000
# 1987  19000
# 63    55000
# 2076  65000
# 1859  60000
# 1704  18000
# 2004  27000

# %%
retailurl = 'https://api.census.gov/data/2022/acs/acsse?get=NAME,K202403_006E&for=place:*&key=0184431db018484fc683ae64e25db82f73d35f0b'

retailresponse = requests.get(retailurl)

retailjson_response = retailresponse.json()

retail_data = pd.DataFrame(retailjson_response[1:], columns=retailjson_response[0])

retail_data = retail_data.rename(columns={'K202403_006E': 'Total Employed in Retail'})

retail_data = retail_data.dropna()

retail_data = retail_data.loc[(retail_data['Total Employed in Retail']) != '0']

retail_data['Total Employed in Retail'] = retail_data['Total Employed in Retail'].astype(int)

retail_data = retail_data.sort_values('Total Employed in Retail', ascending=False)

retail_data.head(10)
# Out:
#                                  NAME  Total Employed in Retail state  place
# 1591          New York city, New York                    362662    36  51000
# 271      Los Angeles city, California                    196369    06  44000
# 2018              Houston city, Texas                    125409    48  35000
# 853            Chicago city, Illinois                    124498    17  14000
# 63              Phoenix city, Arizona                    105292    04  55000
# 2076          San Antonio city, Texas                     84745    48  65000
# 1859  Philadelphia city, Pennsylvania                     75309    42  60000
# 1987               Dallas city, Texas                     73676    48  19000
# 372        San Diego city, California                     65246    06  66000
# 603        Jacksonville city, Florida                     62090    12  35000

# %%
transportationurl = 'https://api.census.gov/data/2022/acs/acsse?get=NAME,K202403_007E&for=place:*&key=0184431db018484fc683ae64e25db82f73d35f0b'

transportationresponse = requests.get(transportationurl)

transportationjson_response = transportationresponse.json()

transportation_data = pd.DataFrame(transportationjson_response[1:], columns=transportationjson_response[0])

transportation_data = transportation_data.rename(columns={'K202403_007E': 'Total Employed in Transportation'})

transportation_data = transportation_data.dropna()

transportation_data = transportation_data.loc[(transportation_data['Total Employed in Transportation']) != '0']

transportation_data['Total Employed in Transportation'] = transportation_data['Total Employed in Transportation'].astype(int)

transportation_data = transportation_data.sort_values('Total Employed in Transportation', ascending=False)

transportation_data.head(10)
# Out:
#                                  NAME  Total Employed in Transportation state  \
# 1591          New York city, New York                            281079    36
# 271      Los Angeles city, California                            107301    06
# 853            Chicago city, Illinois                            105183    17
# 2018              Houston city, Texas                             83181    48
# 63              Phoenix city, Arizona                             57540    04
# 1987               Dallas city, Texas                             48527    48
# 2004           Fort Worth city, Texas                             47368    48
# 1937          Memphis city, Tennessee                             46200    47
# 1859  Philadelphia city, Pennsylvania                             44650    42
# 1704              Columbus city, Ohio                             41203    39
#
#       place
# 1591  51000
# 271   44000
# 853   14000
# 2018  35000
# 63    55000
# 1987  19000
# 2004  27000
# ...

# %%
infourl = 'https://api.census.gov/data/2022/acs/acsse?get=NAME,K202403_008E&for=place:*&key=0184431db018484fc683ae64e25db82f73d35f0b'

inforesponse = requests.get(infourl)

infojson_response = inforesponse.json()

info_data = pd.DataFrame(infojson_response[1:], columns=infojson_response[0])

info_data = info_data.rename(columns={'K202403_008E': 'Total Employed in Information'})

info_data = info_data.dropna()

info_data = info_data.loc[(info_data['Total Employed in Information']) != '0']

info_data['Total Employed in Information'] = info_data['Total Employed in Information'].astype(int)

info_data = info_data.sort_values('Total Employed in Information', ascending=False)

info_data.head(10)
# Out:
#                                        NAME  Total Employed in Information  \
# 1591                New York city, New York                         165682
# 271            Los Angeles city, California                         130212
# 2285               Seattle city, Washington                          32982
# 853                  Chicago city, Illinois                          29720
# 375          San Francisco city, California                          28320
# 379               San Jose city, California                          27638
# 1955                     Austin city, Texas                          22151
# 468                   Denver city, Colorado                          16823
# 372              San Diego city, California                          16369
# 527   Washington city, District of Columbia                          15429
#
#      state  place
# 1591    36  51000
# 271     06  44000
# 2285    53  63000
# 853     17  14000
# 375     06  67000
# 379     06  68000
# ...

# %%
finurl = 'https://api.census.gov/data/2022/acs/acsse?get=NAME,K202403_009E&for=place:*&key=0184431db018484fc683ae64e25db82f73d35f0b'

finresponse = requests.get(finurl)

finjson_response = finresponse.json()

fin_data = pd.DataFrame(finjson_response[1:], columns=finjson_response[0])

fin_data = fin_data.rename(columns={'K202403_009E': 'Total Employed in Finance and Real Estate'})

fin_data = fin_data.dropna()

fin_data = fin_data.loc[(fin_data['Total Employed in Finance and Real Estate']) != '0']

fin_data['Total Employed in Finance and Real Estate'] = fin_data['Total Employed in Finance and Real Estate'].astype(int)

fin_data = fin_data.sort_values('Total Employed in Finance and Real Estate', ascending=False)

fin_data.head(10)
# Out:
#                                  NAME  \
# 1591          New York city, New York
# 853            Chicago city, Illinois
# 271      Los Angeles city, California
# 63              Phoenix city, Arizona
# 1636   Charlotte city, North Carolina
# 2018              Houston city, Texas
# 1987               Dallas city, Texas
# 2076          San Antonio city, Texas
# 603        Jacksonville city, Florida
# 1859  Philadelphia city, Pennsylvania
#
#       Total Employed in Finance and Real Estate state  place
# 1591                                     373328    36  51000
# 853                                      128461    17  14000
# 271                                      110895    06  44000
# 63                                        85216    04  55000
# 1636                                      77378    37  12000
# 2018                                      70158    48  35000
# 1987                                      67818    48  19000
# ...

# %%
prourl = 'https://api.census.gov/data/2022/acs/acsse?get=NAME,K202403_010E&for=place:*&key=0184431db018484fc683ae64e25db82f73d35f0b'

proresponse = requests.get(prourl)

projson_response = proresponse.json()

pro_data = pd.DataFrame(projson_response[1:], columns=projson_response[0])

pro_data = pro_data.rename(columns={'K202403_010E': 'Total Employed in Professional, scientific, and management, and administrative and waste management services'})

pro_data = pro_data.dropna()

pro_data = pro_data.loc[(pro_data['Total Employed in Professional, scientific, and management, and administrative and waste management services']) != '0']

pro_data['Total Employed in Professional, scientific, and management, and administrative and waste management services'] = pro_data['Total Employed in Professional, scientific, and management, and administrative and waste management services'].astype(int)

pro_data = pro_data.sort_values('Total Employed in Professional, scientific, and management, and administrative and waste management services', ascending=False)

pro_data.head(10)
# Out:
#                                 NAME  \
# 1591         New York city, New York
# 271     Los Angeles city, California
# 853           Chicago city, Illinois
# 2018             Houston city, Texas
# 1955              Austin city, Texas
# 372       San Diego city, California
# 375   San Francisco city, California
# 63             Phoenix city, Arizona
# 1987              Dallas city, Texas
# 2285        Seattle city, Washington
#
#       Total Employed in Professional, scientific, and management, and administrative and waste management services  \
# 1591                                             603458
# 271                                              313585
# 853                                              252738
# 2018                                             185635
# 1955                                             140354
# 372                                              133732
# 375                                              127096
# ...

# %%
eduurl = 'https://api.census.gov/data/2022/acs/acsse?get=NAME,K202403_011E&for=place:*&key=0184431db018484fc683ae64e25db82f73d35f0b'

eduresponse = requests.get(eduurl)

edujson_response = eduresponse.json()

edu_data = pd.DataFrame(edujson_response[1:], columns=edujson_response[0])

edu_data = edu_data.rename(columns={'K202403_011E': 'Total Employed in Education and Health'})

edu_data = edu_data.dropna()

edu_data = edu_data.loc[(edu_data['Total Employed in Education and Health']) != '0']

edu_data['Total Employed in Education and Health'] = edu_data['Total Employed in Education and Health'].astype(int)

edu_data = edu_data.sort_values('Total Employed in Education and Health', ascending=False)

edu_data.head(10)
# Out:
#                                  NAME  Total Employed in Education and Health  \
# 1591          New York city, New York                                 1135857
# 271      Los Angeles city, California                                  397881
# 853            Chicago city, Illinois                                  326116
# 1859  Philadelphia city, Pennsylvania                                  249246
# 2018              Houston city, Texas                                  220319
# 63              Phoenix city, Arizona                                  164815
# 372        San Diego city, California                                  163883
# 2076          San Antonio city, Texas                                  162562
# 1179       Boston city, Massachusetts                                  121683
# 1987               Dallas city, Texas                                  117604
#
#      state  place
# 1591    36  51000
# 271     06  44000
# 853     17  14000
# 1859    42  60000
# ...

# %%
arturl = 'https://api.census.gov/data/2022/acs/acsse?get=NAME,K202403_012E&for=place:*&key=0184431db018484fc683ae64e25db82f73d35f0b'

artresponse = requests.get(arturl)

artjson_response = artresponse.json()

art_data = pd.DataFrame(artjson_response[1:], columns=artjson_response[0])

art_data = art_data.rename(columns={'K202403_012E': 'Total Employed in Arts, Entertainment, and Food'})

art_data = art_data.dropna()

art_data = art_data.loc[(art_data['Total Employed in Arts, Entertainment, and Food']) != '0']

art_data['Total Employed in Arts, Entertainment, and Food'] = art_data['Total Employed in Arts, Entertainment, and Food'].astype(int)

art_data = art_data.sort_values('Total Employed in Arts, Entertainment, and Food', ascending=False)

art_data.head(10)
# Out:
#                                  NAME  \
# 1591          New York city, New York
# 271      Los Angeles city, California
# 853            Chicago city, Illinois
# 2018              Houston city, Texas
# 2076          San Antonio city, Texas
# 63              Phoenix city, Arizona
# 372        San Diego city, California
# 1446           Las Vegas city, Nevada
# 1859  Philadelphia city, Pennsylvania
# 1987               Dallas city, Texas
#
#       Total Employed in Arts, Entertainment, and Food state  place
# 1591                                           378104    36  51000
# 271                                            246240    06  44000
# 853                                            121411    17  14000
# 2018                                           106910    48  35000
# 2076                                            83947    48  65000
# 63                                              81548    04  55000
# 372                                             78661    06  66000
# ...

# %%
otherurl = 'https://api.census.gov/data/2022/acs/acsse?get=NAME,K202403_013E&for=place:*&key=0184431db018484fc683ae64e25db82f73d35f0b'

otherresponse = requests.get(otherurl)

otherjson_response = otherresponse.json()

other_data = pd.DataFrame(otherjson_response[1:], columns=otherjson_response[0])

other_data = other_data.rename(columns={'K202403_013E': 'Total Employed in Others, except public administration'})

other_data = other_data.dropna()

other_data = other_data.loc[(other_data['Total Employed in Others, except public administration']) != '0']

other_data['Total Employed in Others, except public administration'] = other_data['Total Employed in Others, except public administration'].astype(int)

other_data = other_data.sort_values('Total Employed in Others, except public administration', ascending=False)

other_data.head(10)
# Out:
#                                        NAME  \
# 1591                New York city, New York
# 271            Los Angeles city, California
# 853                  Chicago city, Illinois
# 2018                    Houston city, Texas
# 527   Washington city, District of Columbia
# 63                    Phoenix city, Arizona
# 1859        Philadelphia city, Pennsylvania
# 372              San Diego city, California
# 1987                     Dallas city, Texas
# 2076                San Antonio city, Texas
#
#       Total Employed in Others, except public administration state  place
# 1591                                             212128         36  51000
# 271                                              118803         06  44000
# 853                                               66739         17  14000
# 2018                                              60570         48  35000
# 527                                               39280         11  50000
# ...

# %%
#pull API URL
paurl = 'https://api.census.gov/data/2022/acs/acsse?get=NAME,K202403_014E&for=place:*&key=0184431db018484fc683ae64e25db82f73d35f0b'

#do request for pull
paresponse = requests.get(paurl)

#convert request to json
pajson_response = paresponse.json()

#turn json response into a dataframe and adjust the second row to the column headers
pa_data = pd.DataFrame(pajson_response[1:], columns=pajson_response[0])

#rename column for group name we are pulling data frame to a clear column name
pa_data = pa_data.rename(columns={'K202403_014E': 'Total Employed in Public Administration'})

#drop na
pa_data = pa_data.dropna()

#filter out cities with 0 
pa_data = pa_data.loc[(pa_data['Total Employed in Public Administration']) != '0']

#Change estimate totals to integer
pa_data['Total Employed in Public Administration'] = pa_data['Total Employed in Public Administration'].astype(int)

#Sort the Estimate totals
pa_data = pa_data.sort_values('Total Employed in Public Administration', ascending=False)

#display top 10
pa_data.head(10)
# Out:
#                                        NAME  \
# 1591                New York city, New York
# 527   Washington city, District of Columbia
# 271            Los Angeles city, California
# 853                  Chicago city, Illinois
# 1859        Philadelphia city, Pennsylvania
# 1955                     Austin city, Texas
# 365             Sacramento city, California
# 2076                San Antonio city, Texas
# 372              San Diego city, California
# 1107               Baltimore city, Maryland
#
#       Total Employed in Public Administration state  place
# 1591                                   156404    36  51000
# 527                                     67994    11  50000
# 271                                     48614    06  44000
# 853                                     46406    17  14000
# 1859                                    42500    42  60000
# 1955                                    32750    48  05000
# 365                                     31807    06  64000
# ...
